# %% [markdown]
# # **Task 1 - Implement a Simple RNN to Predict the Next Value in a Small Sequence of Numbers**
#
# ***Read the following descriptions and instructions***
#
# In time-series analysis, predicting future values based on past observations is a fundamental task. Recurrent Neural Networks (RNNs) are particularly well-suited for this type of problem due to their ability to maintain a memory of previous inputs through their recurrent connections.
#
# In this task, you will work with a synthetic dataset that represents a simple sine wave. The sine wave is a periodic function and serves as a good example to understand how RNNs can capture patterns and make predictions.
#
# A **sine wave** is a fundamental waveform that is widely used in various fields, including signal processing, physics, and time-series analysis. It is characterized by its smooth, periodic oscillations, making it an ideal example for understanding time-series prediction tasks.![11.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %% [markdown]
# The generate_sine_wave function generates a synthetic sine wave dataset, which is often used in time-series prediction tasks, particularly for training models like RNNs and LSTMs.
#
#
# **seq_length=100**: This parameter is intended to specify the length of the sequence that you want to generate
#
# **num_samples=1000**:This parameter determines the number of data points (samples) to generate for the sine wave.

# %%
# 1. Generate a Synthetic Sine Wave Dataset
def generate_sine_wave(seq_length=100, num_samples=1000):
    x = np.linspace(0, 50, num_samples)
    y = np.sin(x)
    return y

# %% [markdown]
# The create_dataset function prepares the sine wave data for use in an RNN by converting the continuous data into sequences that the RNN can learn from. The time_step parameter in the create_dataset function represents the number of previous time points (or observations) that are used as input to predict the next time point in a sequence.

# %%
# 2. Prepare the Dataset for RNN
def create_dataset(data, time_step=10):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step)])
        y.append(data[i + time_step])
    return np.array(X), np.array(y)

# %% [markdown]
# To prepare the data for modeling, it is important to normalize it so that all values fall within a specific range, typically between 0 and 1. This step improves the performance and convergence of neural network models.
#
# The MinMaxScaler from sklearn.preprocessing is used for this purpose. It scales the data such that the minimum value of the data becomes 0 and the maximum value becomes 1.
#
# The sine wave data is reshaped into a 2D array (-1, 1) to fit the scaler, as it expects a 2D input. After scaling, the data is reshaped back into its original 1D form.

# %%
# Generate and Normalize the Data
data = generate_sine_wave()
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data.reshape(-1, 1)).reshape(-1)

# %%
# Create the Dataset
time_step = 10  # Time steps for RNN input
X, y = create_dataset(data, time_step)

# %%
# Reshape for RNN input [samples, time steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# %% [markdown]
# This division of data helps in evaluating the model’s performance by training it on a substantial portion of the data and testing its predictions on unseen data.

# %%
# Split the Data into Training and Testing Sets (80% train, 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# ***Modify the units parameter in the SimpleRNN layer to see how the number of hidden units affects the model's ability to learn the sequence.***
#
#
# **optimizer='adam':** Uses the Adam optimizer, which is a popular choice for training deep learning models due to its adaptive learning rate.
#
#
# **loss='mean_squared_error':** Sets the loss function to mean squared error (MSE), which is commonly used for regression tasks to measure the average squared difference between predicted and actual values.

# %%
# 3. Define the RNN Model
model = Sequential()
model.add(SimpleRNN(units=20, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# g:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ***Adjust the epochs and batch_size during the training phase to optimize the model's learning process and performance.***
#
# an
#
# **epochs=20:** Specifies the number of times the entire training dataset will pass through the model.
#
#
# **batch_size=32:** Determines the number of samples per gradient update.
#
# **verbose=1:** Provides detailed output during training, including the progress of each epoch and loss values.

# %%
# 4. Train the Model
model.fit(X_train, y_train, epochs=40, batch_size=64, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'
# Out:
# Epoch 1/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - loss: 0.1998
# Epoch 2/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0323
# Epoch 3/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109
# Epoch 4/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057
# Epoch 5/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036
# Epoch 6/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027
# Epoch 7/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021
# Epoch 8/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017
# Epoch 9/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014
# Epoch 10/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 11/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.8490e-04
# Epoch 12/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8731e-04
# Epoch 13/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6636e-04
# Epoch 14/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4361e-04
# Epoch 15/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8323e-04
# Epoch 16/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3398e-04
# Epoch 17/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2876e-04
# Epoch 18/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.8314e-04
# Epoch 19/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.6313e-04
# Epoch 20/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1557e-04
# Epoch 21/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2611e-04
# Epoch 22/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.0316e-04
# Epoch 23/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9917e-04
# Epoch 24/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6832e-04
# Epoch 25/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4357e-04
# Epoch 26/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9608e-04
# Epoch 27/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5041e-04
# Epoch 28/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6721e-04
# Epoch 29/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3830e-04
# Epoch 30/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9968e-04
# Epoch 31/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9357e-04
# Epoch 32/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9188e-04
# Epoch 33/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4803e-04
# Epoch 34/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4342e-04
# Epoch 35/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2977e-04
# Epoch 36/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2019e-04
# Epoch 37/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0044e-04
# Epoch 38/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7181e-04
# Epoch 39/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9380e-04
# Epoch 40/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6938e-04

# %%
# 5. Predict on the Test Data
y_pred = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step

# %% [markdown]
# These steps reverse the normalization applied earlier to the predictions and actual values. Normalization scales the data to a range, typically [0, 1], which helps with model training but makes the results difficult to interpret directly.
# By applying the inverse transformation, you convert the scaled predictions (y_pred) and test values (y_test) back to their original scale, allowing you to evaluate and visualize the model's performance in the context of the original data values.

# %%
# Inverse transform to get the original scale (if normalization was applied)
y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1)).reshape(-1)
y_test = scaler.inverse_transform(y_test.reshape(-1, 1)).reshape(-1)

# %% [markdown]
# This plot visually compares the actual sine wave values (y_test) with the values predicted by the RNN model (y_pred).
#
# By plotting both sets of values on the same graph, you can easily see how well the model's predictions align with the actual data.
#
# This visualization helps in assessing the performance of the RNN model and understanding how accurately it captures the underlying pattern in the time series data.
#
# ***Analyze the resulting plot. If the predicted values deviate significantly from the actual values, experiment with different model configurations and training parameters to improve accuracy.***
#
# # **Describe your observations. You can add a text cell and type your observations.**

# %%
# 6. Plot the Results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()

# %% [markdown]
# Above is Lab 4 default

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()

# %%
model1 = Sequential()
model1.add(SimpleRNN(units=10, return_sequences=False, input_shape=(time_step, 1)))
model1.add(Dense(1))
model1.compile(optimizer='adam', loss='mean_squared_error')

model1.fit(X_train, y_train, epochs=20, batch_size=64, verbose=1)

y_pred1 = model1.predict(X_test)
y_pred1 = scaler.inverse_transform(y_pred1.reshape(-1, 1)).reshape(-1)
y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1)).reshape(-1)

plt.figure(figsize=(12, 6))
plt.plot(y_test_orig, label='Actual')
plt.plot(y_pred1, label='Predicted - Model 1')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction - Model 1')
plt.legend()
plt.show()
# Out:
# g:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - loss: 1.0740
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5216
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2166
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0826
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0448
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0355
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0290
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0231
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0197
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0159
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0132
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0109
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0087
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0068
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0054
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0043
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0032
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0024
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step

# %%
model2 = Sequential()
model2.add(SimpleRNN(units=50, return_sequences=False, input_shape=(time_step, 1)))
model2.add(Dense(1))
model2.compile(optimizer='adam', loss='mean_squared_error')

model2.fit(X_train, y_train, epochs=80, batch_size=32, verbose=1)

y_pred2 = model2.predict(X_test)
y_pred2 = scaler.inverse_transform(y_pred2.reshape(-1, 1)).reshape(-1)

plt.figure(figsize=(12, 6))
plt.plot(y_test_orig, label='Actual')
plt.plot(y_pred2, label='Predicted - Model 2')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction - Model 2')
plt.legend()
plt.show()
# Out:
# Epoch 1/80
# g:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0709
# Epoch 2/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0087
# Epoch 3/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013
# Epoch 4/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.7882e-04
# Epoch 5/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8815e-04
# Epoch 6/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5430e-04
# Epoch 7/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9544e-04
# Epoch 8/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8323e-04
# Epoch 9/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5762e-04
# Epoch 10/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9777e-04
# Epoch 11/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7938e-04
# Epoch 12/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7639e-04
# Epoch 13/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4118e-04
# Epoch 14/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0855e-04
# Epoch 15/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1543e-04
# Epoch 16/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7092e-05
# Epoch 17/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7972e-05
# Epoch 18/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.5526e-05
# Epoch 19/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.5918e-05
# Epoch 20/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0317e-05
# Epoch 21/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9338e-05
# Epoch 22/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8873e-05
# Epoch 23/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7641e-05
# Epoch 24/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5065e-05
# Epoch 25/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0700e-05
# Epoch 26/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7150e-05
# Epoch 27/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5730e-05
# Epoch 28/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2870e-05
# Epoch 29/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3414e-05
# Epoch 30/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1349e-05
# Epoch 31/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7035e-05
# Epoch 32/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5984e-05
# Epoch 33/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9490e-05
# Epoch 34/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2068e-05
# Epoch 35/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3847e-05
# Epoch 36/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2855e-05
# Epoch 37/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2655e-05
# Epoch 38/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3178e-05
# Epoch 39/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1363e-05
# Epoch 40/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0262e-05
# Epoch 41/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0318e-05
# Epoch 42/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.1206e-05
# Epoch 43/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1830e-05
# Epoch 44/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6390e-05
# Epoch 45/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7120e-06
# Epoch 46/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7177e-06
# Epoch 47/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7676e-06
# Epoch 48/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0581e-05
# Epoch 49/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9336e-06
# Epoch 50/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1105e-05
# Epoch 51/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4956e-06
# Epoch 52/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3084e-06
# Epoch 53/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4098e-06
# Epoch 54/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1614e-06
# Epoch 55/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2996e-06
# Epoch 56/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0012e-06
# Epoch 57/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1114e-06
# Epoch 58/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.6290e-06
# Epoch 59/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.0584e-06
# Epoch 60/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2450e-06
# Epoch 61/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4167e-06
# Epoch 62/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3195e-06
# Epoch 63/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0073e-06
# Epoch 64/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4108e-06
# Epoch 65/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2935e-06
# Epoch 66/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9179e-06
# Epoch 67/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8903e-06
# Epoch 68/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8060e-06
# Epoch 69/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6737e-06
# Epoch 70/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3732e-06
# Epoch 71/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1591e-06
# Epoch 72/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6051e-06
# Epoch 73/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0545e-06
# Epoch 74/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3065e-05
# Epoch 75/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0634e-06
# Epoch 76/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1513e-06
# Epoch 77/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8660e-06
# Epoch 78/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8762e-06
# Epoch 79/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 9.7871e-06
# Epoch 80/80
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.1187e-06
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002427FF6F6A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step

# %%
model3 = Sequential()
model3.add(SimpleRNN(units=100, return_sequences=False, input_shape=(time_step, 1)))
model3.add(Dense(1))
model3.compile(optimizer='adam', loss='mean_squared_error')

model3.fit(X_train, y_train, epochs=100, batch_size=16, verbose=1)

y_pred3 = model3.predict(X_test)
y_pred3 = scaler.inverse_transform(y_pred3.reshape(-1, 1)).reshape(-1)

plt.figure(figsize=(12, 6))
plt.plot(y_test_orig, label='Actual')
plt.plot(y_pred3, label='Predicted - Model 3')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction - Model 3')
plt.legend()
plt.show()
# Out:
# g:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0945
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 1.2949e-04
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0607e-04
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6954e-05
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3789e-04
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.7103e-04
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0170e-04
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1019e-05
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8967e-05
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.3097e-04
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6382e-05
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1185e-05
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8830e-05
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7948e-05
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9194e-05
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7476e-05
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1312e-05
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1365e-05
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7786e-04
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.8932e-05
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.0111e-05
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4263e-05
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4656e-05
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6848e-05
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7496e-05
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4622e-05
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9423e-06
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2996e-05
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.3602e-04
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 8.2684e-05
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5798e-05
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3672e-05
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1978e-05
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7451e-05
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3102e-05
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 8.3633e-06
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5205e-05
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.5177e-06
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.2336e-06
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9361e-06
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2141e-05
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1624e-06
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6826e-06
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3056e-06
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5602e-06
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6630e-06
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.3959e-06
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.8831e-06
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.6064e-06
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7236e-04
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5663e-04
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6983e-06
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9506e-06
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2536e-06
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7457e-06
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4953e-06
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2635e-06
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8267e-06
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5489e-06
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6342e-06
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6180e-06
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1762e-06
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2153e-06
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6428e-06
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1066e-06
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4493e-06
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0602e-06
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8878e-06
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1404e-06
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7121e-07
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.6484e-07
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.1941e-07
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.7251e-07
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0276e-06
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3517e-07
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7018e-07
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4784e-07
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2871e-07
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4322e-06
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1568e-06
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3823e-07
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2222e-06
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4746e-06
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.1469e-06
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4879e-06
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0164e-06
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5991e-06
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0216e-06
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7290e-06
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1539e-05
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2643e-06
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1672e-06
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1339e-06
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8958e-07
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3787e-05
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7691e-05
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0146e-06
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6467e-06
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000024202977F60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step

# %%
model4 = Sequential()
model4.add(SimpleRNN(units=20, return_sequences=False, input_shape=(time_step, 1)))
model4.add(Dense(1))
model4.compile(optimizer='adam', loss='mean_squared_error')

model4.fit(X_train, y_train, epochs=40, batch_size=64, verbose=1)

y_pred4 = model4.predict(X_test)
y_pred4 = scaler.inverse_transform(y_pred4.reshape(-1, 1)).reshape(-1)
y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1)).reshape(-1)

# Plot predictions
plt.figure(figsize=(12, 6))
plt.plot(y_test_orig, label='Actual')
plt.plot(y_pred4, label='Predicted - Model 4')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction - Model 4 (Units=23, Epochs=50, Batch=64)')
plt.legend()
plt.show()
# Out:
# g:\Anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - loss: 0.0239
# Epoch 2/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0039
# Epoch 3/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0014
# Epoch 4/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 6.2313e-04
# Epoch 5/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.7947e-04
# Epoch 6/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.5204e-04
# Epoch 7/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.0953e-04
# Epoch 8/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7528e-04
# Epoch 9/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3995e-04
# Epoch 10/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2578e-04
# Epoch 11/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1393e-04
# Epoch 12/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.2682e-04
# Epoch 13/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7136e-04
# Epoch 14/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5884e-04
# Epoch 15/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4015e-04
# Epoch 16/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4492e-04
# Epoch 17/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1779e-04
# Epoch 18/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9432e-04
# Epoch 19/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8887e-04
# Epoch 20/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8644e-04
# Epoch 21/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7119e-04
# Epoch 22/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7033e-04
# Epoch 23/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4685e-04
# Epoch 24/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4033e-04
# Epoch 25/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2932e-04
# Epoch 26/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2151e-04
# Epoch 27/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0655e-04
# Epoch 28/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5564e-05
# Epoch 29/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7851e-05
# Epoch 30/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6643e-05
# Epoch 31/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6451e-05
# Epoch 32/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0560e-05
# Epoch 33/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2369e-05
# Epoch 34/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9610e-05
# Epoch 35/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.0620e-05
# Epoch 36/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.8402e-05
# Epoch 37/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9488e-05
# Epoch 38/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.9597e-05
# Epoch 39/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1964e-05
# Epoch 40/40
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.9620e-05
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
